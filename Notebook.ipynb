# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
import polars as pl

df = pd.read_csv("products.csv")

# %%
df.head(10)
# Out:
#    row num                     product_name             category  \
# 0        1  Pet Camera with Treat Dispenser                 Pets
# 1        2           Whole Wheat Pita Bread         Food - Bread
# 2        3                     Cocoa Powder        Food - Baking
# 3        4   Roasted Garlic Mashed Potatoes  Food - Frozen Foods
# 4        5             Mini Electric Kettle              Kitchen
# 5        6                   Blackberry Jam    Food - Condiments
# 6        7    Multicolored LED Strip Lights                 Home
# 7        8             Sriracha Chili Sauce    Food - Condiments
# 8        9             Automatic Pet Feeder                 Pets
# 9       10                Coconut Oil Spray  Food - Cooking Oils
#
#                                          description   price
# 0  Monitor and interact with your pet remotely wi...  351.19
# 1  Soft and fluffy whole wheat pita bread, great ...  432.21
# 2  Rich cocoa powder for baking and chocolate rec...  131.11
# ...

# %%
df.iloc[0][3]
# Out:
# /tmp/ipykernel_303056/3304378415.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][3]
# 'Monitor and interact with your pet remotely with this camera.'

# %%
df.shape
# Out:
# (100, 5)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Semantic Search

# %%
def preprocess_text(text):
    """ Convert text to lowercase and remove extra space""" 
    return text.lower().strip()

# %%
df["description"]=df["description"].apply(preprocess_text)

# %%
df.head()
# Out:
#    row num                     product_name             category  \
# 0        1  Pet Camera with Treat Dispenser                 Pets
# 1        2           Whole Wheat Pita Bread         Food - Bread
# 2        3                     Cocoa Powder        Food - Baking
# 3        4   Roasted Garlic Mashed Potatoes  Food - Frozen Foods
# 4        5             Mini Electric Kettle              Kitchen
#
#                                          description   price
# 0  monitor and interact with your pet remotely wi...  351.19
# 1  soft and fluffy whole wheat pita bread, great ...  432.21
# 2  rich cocoa powder for baking and chocolate rec...  131.11
# 3  creamy mashed potatoes infused with roasted ga...  579.19
# 4  quick boiling kettle for small kitchens and do...  546.43

# %%
pldf = pl.read_csv("products.csv")
pldf.head(10)
# Out:
# shape: (10, 5)
# ┌─────────┬────────────────────────┬─────────────────────┬────────────────────────────────┬────────┐
# │ row num ┆ product_name           ┆ category            ┆ description                    ┆ price  │
# │ ---     ┆ ---                    ┆ ---                 ┆ ---                            ┆ ---    │
# │ i64     ┆ str                    ┆ str                 ┆ str                            ┆ f64    │
# ╞═════════╪════════════════════════╪═════════════════════╪════════════════════════════════╪════════╡
# │ 1       ┆ Pet Camera with Treat  ┆ Pets                ┆ Monitor and interact with      ┆ 351.19 │
# │         ┆ Dispense…              ┆                     ┆ your…                          ┆        │
# │ 2       ┆ Whole Wheat Pita Bread ┆ Food - Bread        ┆ Soft and fluffy whole wheat    ┆ 432.21 │
# │         ┆                        ┆                     ┆ pi…                            ┆        │
# ...

# %%
# pldf['all'] =pldf['product_name']+", "+pldf["category"]+", "+pldf['description']
# pldf['all'] = pldf.with_columns(pl.col("product_name")+", "+pl.col("category")) 
pldf = pldf.with_columns(pl.concat_str(["product_name", "category", "description"], separator=", ").alias("all"))
pldf.head(10)
# Out:
# shape: (10, 6)
# ┌─────────┬───────────────────┬───────────────────┬───────────────────┬────────┬───────────────────┐
# │ row num ┆ product_name      ┆ category          ┆ description       ┆ price  ┆ all               │
# │ ---     ┆ ---               ┆ ---               ┆ ---               ┆ ---    ┆ ---               │
# │ i64     ┆ str               ┆ str               ┆ str               ┆ f64    ┆ str               │
# ╞═════════╪═══════════════════╪═══════════════════╪═══════════════════╪════════╪═══════════════════╡
# │ 1       ┆ Pet Camera with   ┆ Pets              ┆ Monitor and       ┆ 351.19 ┆ Pet Camera with   │
# │         ┆ Treat Dispense…   ┆                   ┆ interact with     ┆        ┆ Treat Dispense…   │
# │         ┆                   ┆                   ┆ your…             ┆        ┆                   │
# │ 2       ┆ Whole Wheat Pita  ┆ Food - Bread      ┆ Soft and fluffy   ┆ 432.21 ┆ Whole Wheat Pita  │
# ...
